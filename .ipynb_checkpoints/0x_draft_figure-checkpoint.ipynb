# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import altair as alt
import math

plt.style.use('default')
plt.rcParams["font.family"] = "Tahoma"

df_ebola = pd.read_csv('ebola.csv')
df_h1n1 = pd.read_csv('h1n1.csv')
df_mers = pd.read_csv('mers_cov.csv')
df_sars = pd.read_csv('sars_cov1.csv')
df_measles = pd.read_csv('measles.csv')
df_polio = pd.read_csv('polio.csv')

df_ebola['disease'] = 'ebola'
df_h1n1['disease'] = 'h1n1'
df_mers['disease'] = 'mers_cov'
df_sars['disease'] = 'sars'
df_measles['disease'] = 'measles'
df_polio['disease'] = 'polio'
df_polio = df_polio.rename(columns={'infection_incidence_count (wild)': 'infection_incidence_count',\
                                    'vaccination_licensed':'licensed_vaccine'})
df_sars = df_sars.rename(columns={'infection_incidence_count (wild)': 'infection_incidence_count',\
                                    'vaccination_licensed':'licensed_vaccine'})
df_mers = df_mers.rename(columns={'infection_incidence_count (wild)': 'infection_incidence_count',\
                                    'vaccination_licensed':'licensed_vaccine'})
df_ebola = df_ebola.rename(columns={'declared_pandemic_outbreak': 'declared_pandemic'})
frames = [df_ebola, df_h1n1, df_mers, df_sars, df_measles, df_polio]

#concatenate dataframes
df = pd.concat(frames, sort=True)
years = df['year'].unique().tolist()
years.sort()
years = years[-21:]
diseases = df['disease'].unique().tolist()

df_polio
# Out:
#      year  linked_to_disease  declared_pandemic  licensed_vaccine  \
# 0    1916               True               True             False
# 1    1917              False              False             False
# 2    1918              False              False             False
# 3    1919              False              False             False
# 4    1920              False              False             False
# 5    1921              False              False             False
# 6    1922              False              False             False
# 7    1923              False              False             False
# 8    1924              False              False             False
# 9    1925              False              False             False
# 10   1926              False              False             False
# 11   1927              False              False             False
# 12   1928              False              False             False
# 13   1929              False              False             False
# 14   1930              False              False             False
# 15   1931              False              False             False
# 16   1932              False              False             False
# 17   1933              False              False             False
# 18   1934              False              False             False
# 19   1935              False              False             False
# 20   1936              False              False             False
# 21   1937              False              False             False
# 22   1938              False              False             False
# 23   1939              False              False             False
# 24   1940              False              False             False
# 25   1941              False              False             False
# 26   1942              False              False             False
# 27   1943              False              False             False
# 28   1944              False              False             False
# 29   1945              False              False             False
# ..    ...                ...                ...               ...
# 74   1990              False              False             False
# 75   1991              False              False             False
# 76   1992              False              False             False
# 77   1993              False              False             False
# 78   1994              False              False             False
# 79   1995              False              False             False
# 80   1996              False              False             False
# 81   1997              False              False             False
# 82   1998              False              False             False
# 83   1999              False              False             False
# 84   2000              False              False             False
# 85   2001              False              False             False
# 86   2002              False              False             False
# 87   2003              False              False             False
# 88   2004              False              False             False
# 89   2005              False              False             False
# 90   2006              False              False             False
# 91   2007              False              False             False
# 92   2008              False              False             False
# 93   2009              False              False             False
# 94   2010              False              False             False
# 95   2011              False              False             False
# 96   2012              False              False             False
# 97   2013              False              False             False
# 98   2014              False              False             False
# 99   2015              False              False             False
# 100  2016              False              False             False
# 101  2017              False              False             False
# 102  2018              False              False             False
# 103  2019              False              False             False
#
#      infection_incidence_count  infection_incidence_count(vaccine_derived)  \
# 0                          NaN                                         NaN
# 1                          NaN                                         NaN
# 2                          NaN                                         NaN
# 3                          NaN                                         NaN
# 4                          NaN                                         NaN
# 5                          NaN                                         NaN
# 6                          NaN                                         NaN
# 7                          NaN                                         NaN
# 8                          NaN                                         NaN
# 9                          NaN                                         NaN
# 10                         NaN                                         NaN
# 11                         NaN                                         NaN
# 12                         NaN                                         NaN
# 13                         NaN                                         NaN
# 14                         NaN                                         NaN
# 15                         NaN                                         NaN
# 16                         NaN                                         NaN
# 17                         NaN                                         NaN
# 18                         NaN                                         NaN
# 19                         NaN                                         NaN
# 20                         NaN                                         NaN
# 21                         NaN                                         NaN
# 22                         NaN                                         NaN
# 23                         NaN                                         NaN
# 24                         NaN                                         NaN
# 25                         NaN                                         NaN
# 26                         NaN                                         NaN
# 27                         NaN                                         NaN
# 28                         NaN                                         NaN
# 29                         NaN                                         NaN
# ..                         ...                                         ...
# 74                         NaN                                         NaN
# 75                         NaN                                         NaN
# 76                         NaN                                         NaN
# 77                         NaN                                         NaN
# 78                         NaN                                         NaN
# 79                         NaN                                         NaN
# 80                         NaN                                         NaN
# 81                         NaN                                         NaN
# 82                         NaN                                         NaN
# 83                         NaN                                         NaN
# 84                       719.0                                        12.0
# 85                       483.0                                        13.0
# 86                      1918.0                                         4.0
# 87                       784.0                                         0.0
# 88                      1255.0                                         2.0
# 89                      1979.0                                        51.0
# 90                      1997.0                                        25.0
# 91                      1315.0                                        72.0
# 92                      1651.0                                        85.0
# 93                      1604.0                                       184.0
# 94                      1352.0                                        60.0
# 95                       650.0                                        66.0
# 96                       223.0                                        71.0
# 97                        46.0                                        65.0
# 98                       349.0                                        56.0
# 99                        74.0                                        32.0
# 100                       37.0                                         5.0
# 101                       22.0                                        96.0
# 102                       33.0                                       104.0
# 103                      163.0                                       259.0
#
#      \nPolio-compatible case  death_count  \
# 0                        NaN          NaN
# 1                        NaN          NaN
# 2                        NaN          NaN
# 3                        NaN          NaN
# 4                        NaN          NaN
# 5                        NaN          NaN
# 6                        NaN          NaN
# 7                        NaN          NaN
# 8                        NaN          NaN
# 9                        NaN          NaN
# 10                       NaN          NaN
# 11                       NaN          NaN
# 12                       NaN          NaN
# 13                       NaN          NaN
# 14                       NaN          NaN
# 15                       NaN          NaN
# 16                       NaN          NaN
# 17                       NaN          NaN
# 18                       NaN          NaN
# 19                       NaN          NaN
# 20                       NaN          NaN
# 21                       NaN          NaN
# 22                       NaN          NaN
# 23                       NaN          NaN
# 24                       NaN          NaN
# 25                       NaN          NaN
# 26                       NaN          NaN
# 27                       NaN          NaN
# 28                       NaN          NaN
# 29                       NaN          NaN
# ..                       ...          ...
# 74                       NaN          NaN
# 75                       NaN          NaN
# 76                       NaN          NaN
# 77                       NaN          NaN
# 78                       NaN          NaN
# 79                       NaN          NaN
# 80                       NaN          NaN
# 81                       NaN          NaN
# 82                       NaN          NaN
# 83                       NaN          NaN
# 84                    1054.0          NaN
# 85                    1103.0          NaN
# 86                     975.0          NaN
# 87                     621.0          NaN
# 88                     700.0          NaN
# 89                    1001.0          NaN
# 90                     908.0          NaN
# 91                     653.0          NaN
# 92                     855.0          NaN
# 93                     806.0          NaN
# 94                     579.0          NaN
# 95                     480.0          NaN
# 96                     315.0          NaN
# 97                     403.0          NaN
# 98                     285.0          NaN
# 99                     277.0          NaN
# 100                    211.0          NaN
# 101                    259.0          NaN
# 102                    137.0          NaN
# 103                    125.0          NaN
#
#                                                 Source disease
# 0    https://extranet.who.int/polis/public/CaseCoun...   polio
# 1                                                  NaN   polio
# 2                                                  NaN   polio
# 3                                                  NaN   polio
# 4                                                  NaN   polio
# 5                                                  NaN   polio
# 6                                                  NaN   polio
# 7                                                  NaN   polio
# 8                                                  NaN   polio
# 9                                                  NaN   polio
# 10                                                 NaN   polio
# 11                                                 NaN   polio
# 12                                                 NaN   polio
# 13                                                 NaN   polio
# 14                                                 NaN   polio
# 15                                                 NaN   polio
# 16                                                 NaN   polio
# 17                                                 NaN   polio
# 18                                                 NaN   polio
# 19                                                 NaN   polio
# 20                                                 NaN   polio
# 21                                                 NaN   polio
# 22                                                 NaN   polio
# 23                                                 NaN   polio
# 24                                                 NaN   polio
# 25                                                 NaN   polio
# 26                                                 NaN   polio
# 27                                                 NaN   polio
# 28                                                 NaN   polio
# 29                                                 NaN   polio
# ..                                                 ...     ...
# 74                                                 NaN   polio
# 75                                                 NaN   polio
# 76                                                 NaN   polio
# 77                                                 NaN   polio
# 78                                                 NaN   polio
# 79                                                 NaN   polio
# 80                                                 NaN   polio
# 81                                                 NaN   polio
# 82                                                 NaN   polio
# 83                                                 NaN   polio
# 84                                                 NaN   polio
# 85                                                 NaN   polio
# 86                                                 NaN   polio
# 87                                                 NaN   polio
# 88                                                 NaN   polio
# 89                                                 NaN   polio
# 90                                                 NaN   polio
# 91                                                 NaN   polio
# 92                                                 NaN   polio
# 93                                                 NaN   polio
# 94                                                 NaN   polio
# 95                                                 NaN   polio
# 96                                                 NaN   polio
# 97                                                 NaN   polio
# 98                                                 NaN   polio
# 99                                                 NaN   polio
# 100                                                NaN   polio
# 101                                                NaN   polio
# 102                                                NaN   polio
# 103                                                NaN   polio
#
# [104 rows x 10 columns]

# %% [markdown]
# # Test plot
# dot plot: https://stackoverflow.com/questions/49703938/how-to-create-a-dot-plot-in-matplotlib-not-a-scatter-plot

# %%
# diseases.insert(0, '')
# diseases.append('null')
fig, axs = plt.subplots(len(diseases), 1, figsize=(20, 10), sharex=True)
print(diseases)
# axs[-1].set_xticklabels([2000, 2020])
dates = {'linked_to_disease': '#fc8d62', 'declared_pandemic':'#8da0cb', 'licensed_vaccine':'#e78ac3'}


for i, df in enumerate(frames):
    # sample = df.dropna(subset=['infection_incidience_count'])
    axs[i].bar(df['year'], df['infection_incidence_count'], width=1, fc='#66c2a5')# , 'o', ls='-', ms=4)
    limits = [0, math.ceil(df['infection_incidence_count'].max()/1000) * 1000]
#     axs[i].set_ylim(limits)
    axs[i].set_xlim([1950, 2021])
    axs[i].spines['right'].set_visible(False)
    axs[i].spines['top'].set_visible(False)
    axs[i].spines['left'].set_visible(False)
    axs[i].spines['bottom'].set_visible(False)
    axs[i].set_ylabel(df['disease'].unique()[0], rotation='horizontal')
    axs[i].set_yscale('log')
    for date in dates:
        sample = df[df[date] == True]
        for r, row in sample.iterrows():
            color = dates[date]
            axs[i].axvline(row['year'], limits[0], limits[1], c=color, label=date, linewidth=2)
            
    if i == 1:
        axs[i].legend()

fig.savefig('testfig.png')
# Out:
# ['ebola', 'h1n1', 'mers_cov', 'sars', 'measles', 'polio']
# /anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:6652: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)

# %%
from vega_datasets import data

source = data.movies.url

alt.Chart(source).mark_bar().encode(
    alt.X("IMDB_Rating:Q", bin=True),
    y='count()',
)

# %%
data = pd.DataFrame({'a': list('CCCDDDEEE'),
                     'b': [2, 7, 4, 1, 2, 6, 8, 4, 7]})
chart = alt.Chart(data)
alt.Chart(data).mark_point()

# %%
alt.Chart(data).mark_point().encode(
    x='a',
)
